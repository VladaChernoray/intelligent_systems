# %% [markdown]
# TASK 1

# %% [markdown]
# <body>
#     <h1 style="color:MediumSeaGreen"><b>Guyana</b></h1>
#     <p style = "padding: 0 100px 0 0; text-align:justify; font-size:16px;"><b><i>Guyana</i></b> is a country located on the northern coast of South America. It is bordered by Venezuela to the west, Brazil to the south, and Suriname to the east. Its capital and largest city is Georgetown.</p>
#
# <div style="padding: 40px 0">
#     <div style="display: inline-block; padding: 0 20px 0">
#         <img src="https://www.worldatlas.com/r/w1200/upload/cc/72/8c/gy-02.png" style="width: 300px">
#     </div>
#     <div style="display: inline-block; padding: 0 20px 0">
# <table style = "width: 520px; font-size: 16px">
#   <tr>
#     <th style= "text-align: left"><b>Attribute</b></th>
#     <th style= "text-align: left">Value</th>
#   </tr>
#   <tr>
#      <td style= "text-align: left"><b>Official Name</b></td>
#     <td style= "text-align: left">Co-operative Republic of Guyana</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Capital</b></td>
#     <td style= "text-align: left">Georgetown</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Population</b></td>
#     <td style= "text-align: left">786,000 (estimated, 2021)</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Area</b></td>
#     <td style= "text-align: left">214,970 km²</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Currency</b></td>
#     <td style= "text-align: left">Guyanese dollar (GYD)</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Official Language</b></td>
#     <td style= "text-align: left">English</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Government</b></td>
#     <td style= "text-align: left">Unitary presidential constitutional republic</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Time Zone</b></td>
#     <td style= "text-align: left">UTC-4</td>
#   </tr>
# </table>
#     </div>
# </div>
# <h2 style="color:MediumSeaGreen">Flag</h2>
#
# <img alt="Flag of Guyana" style="display: inline-block; padding: 0 20px 0; vertical-align:middle;" src="data:image/svg+xml;charset=utf-8,%3Csvg viewBox='0 0 600 400' xmlns='http://www.w3.org/2000/svg'%3E%3Crect width='600' height='400' fill='%23009E49'/%3E%3Crect width='600' height='133.33' y='133.33' fill='%23FCD116'/%3E%3Crect width='600' height='66.67' y='266.67' fill='%23000000'/%3E%3Ccircle cx='300' cy='200' r='80' fill='%23000000'/%3E%3Ccircle cx='300' cy='200' r='66.67' fill='%23FCD116'/%3E%3Crect x='270' y='160' width='60' height='80' fill='%23009E49'/%3E%3Crect x='300' y='130' width='30' height='140' fill='%23009E49'/%3E%3C/svg%3E" width="400">
# <div style="display: inline-block; padding: 0 20px 0; width: 510px;vertical-align:middle">
#     <p style="text-align:justify; font-size: 16px">The flag of Guyana consists of a green background, representing the country's forests and agriculture. In the center of the flag is a yellow triangle, representing Guyana's mineral wealth. Within the triangle is a black stripe, symbolizing Guyana's diverse population, and two white stripes, representing the rivers of Guyana and the country's commitment to peace. At the top of the flag is a red star, representing the country's socialist revolution and its future aspirations. The flag was adopted on May 26, 1966, when Guyana gained independence from the United Kingdom.</p>
#
# <p style="text-align:justify; font-size: 16px">The colors and symbols on the flag of Guyana carry significant meaning for the people of the country, and the flag is an important national symbol. It is commonly flown at public buildings, events, and ceremonies, and is often used as a symbol of Guyanese identity and pride.</p></div>
#
#
#
# <h2 style="color:MediumSeaGreen">Geography</h2>
# <table style = "width: 700px; font-size: 16px">
#   <tr>
#     <th style= "text-align: left"><b>Attribute</b></th>
#     <th style= "text-align: left">Value</th>
#   </tr>
#   <tr>
#      <td style= "text-align: left"><b>Location</b></td>
#     <td style= "text-align: left">Northeastern coast of South America</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Neighboring Countries</b></td>
#     <td style= "text-align: left">Venezuela, Brazil, and Suriname</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Terrain</b></td>
#     <td style= "text-align: left">Coastal plains, savannas, and rainforests</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Highest Point</b></td>
#     <td style= "text-align: left">Mount Roraima (2,810 meters)</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Longest River</b></td>
#     <td style= "text-align: left">Essequibo River (1,010 km)</td>
#   </tr>
#   <tr>
# </table>
# <h2 style="color:MediumSeaGreen">Culture and Society</h2>
# <table style = "width: 700px; font-size: 16px">
#   <tr>
#     <th style= "text-align: left"><b>Attribute</b></th>
#     <th style= "text-align: left">Value</th>
#   </tr>
#   <tr>
#      <td style= "text-align: left"><b>Ethnic Groups</b></td>
#     <td style= "text-align: left">Indo-Guyanese, Afro-Guyanese, Amerindians, and others</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Religion</b></td>
#     <td style= "text-align: left">Christianity, Hinduism, Islam, and others</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Education</b></td>
#     <td style= "text-align: left">Literacy rate of 88% (estimated, 2021)</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Sports</b></td>
#     <td style= "text-align: left">Cricket is the most popular sport</td>
#   </tr>
# </table>
#
# <h2 style="color:MediumSeaGreen">Economy</h2>
# <table style = "width: 700px; font-size: 16px">
#   <tr>
#     <th style= "text-align: left"><b>Attribute</b></th>
#     <th style= "text-align: left">Value</th>
#   </tr>
#   <tr>
#      <td style= "text-align: left"><b>GDP (PPP)</b></td>
#     <td style= "text-align: left">$8.9 billion (estimated, 2021)</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Major Industries</b></td>
#     <td style= "text-align: left">Agriculture (sugar, rice, and other crops), mining (gold, bauxite, and diamonds), and timber</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Exports</b></td>
#     <td style= "text-align: left">Gold, timber, rice, sugar, and fish</td>
#   </tr>
#   <tr>
#       <td style= "text-align: left"><b>Trade Partners</b></td>
#     <td style= "text-align: left">United States, Canada, and the European Union</td>
#   </tr>
#    <tr>
#       <td style= "text-align: left"><b>Unemployment Rate</b></td>
#     <td style= "text-align: left">11.7% (estimated, 2021)</td>
#   </tr>
# </table>
#
# <h2 style="padding: 50px 0 0; color:MediumSeaGreen">Outstanding personalities from Guyana</h2>
# <div style="padding: 50px 0 0 ">
#    <div style="width:320px; display: inline-block; padding: 20px; background-color: lightGray;">
#    <img src="https://upload.wikimedia.org/wikipedia/commons/6/6d/Forbes_Burnham_%281966%29.jpg" style="width:300px; height: 350px;">
#     <h3><a href="https://en.wikipedia.org/wiki/Forbes_Burnham">Forbes Burnham</a></h3>
#     <p style = "text-align:justify">He was the first Prime Minister of Guyana and later became the country's first executive president. He played a key role in securing Guyana's independence from British colonial rule in 1966.</p>
# </div>
# <div style="width:320px; display: inline-block; padding: 20px;">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Cheddi_Jagan_Anefo.jpg/330px-Cheddi_Jagan_Anefo.jpg"; style="width:300px; height: 350px">
#     <h3><a href="https://en.wikipedia.org/wiki/Cheddi_Jagan">Cheddi Jagan</a></h3>
#     <p style = "text-align:justify">He was a politician and the founder of the People's Progressive Party, which became the ruling party of Guyana after independence. He served as the country's first Premier and later as President.</p>
# </div>
# <div style="width:320px; display: inline-block; padding: 20px; background-color: lightGray;">
# <img src="https://static01.nyt.com/images/2016/12/14/arts/14braithwaite-obit/14braithwaite-obit-superJumbo.jpg?quality=75&auto=webp"; style="width:300px; height: 350px">
#     <h3><a href="https://en.wikipedia.org/wiki/E._R._Braithwaite">E. R. Braithwaite</a></h3>
#     <p style = "text-align:justify">He was a writer and educator who wrote several books, including "To Sir, With Love", which was turned into a popular film. He was also a diplomat, serving as Guyana's ambassador to the United Nations.</p>
# </div>
# <div style="width:320px; display: inline-block; padding: 20px">
# <img src="https://upload.wikimedia.org/wikipedia/commons/8/8b/Janet_Jagan.png"; style="width:300px; height: 350px">
#     <h3><a href="https://en.wikipedia.org/wiki/Janet_Jagan">Janet Jagan</a></h3>
#     <p style = "text-align:justify">She was a politician and the wife of Cheddi Jagan. She served as Guyana's Prime Minister from 1997 to 1999 and later as President from 1999 to 2001, becoming the first woman to hold either position in Guyana.</p>
# </div>
# <div style="width:320px; display: inline-block; padding: 20px; background-color: lightGray;">
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/03/Shivnarine_Chanderpaul.jpg"; style="width:300px; height: 350px">
#     <h3><a href="https://en.wikipedia.org/wiki/Shivnarine_Chanderpaul">Shivnarine Chanderpaul</a></h3>
#     <p style = "text-align:justify">He is a former cricketer who played for the West Indies cricket team and is considered one of the greatest batsmen from the Caribbean. He was born in Guyana and played for the Guyana national cricket team as well.</p>
# </div>
# <div style="width:320px; display: inline-block; padding: 20px">
# <img src="https://static01.nyt.com/images/2018/03/21/obituaries/21harris-print/harris-pic-superJumbo.jpg"; style="width:300px; height: 350px">
#     <h3><a href="https://en.wikipedia.org/wiki/Wilson_Harris">Wilson Harris</a></h3>
#     <p style = "text-align:justify">He was a writer and one of the most important literary figures to come out of Guyana. He wrote several novels, including "Palace of the Peacock" and "The Secret Ladder", which explored themes of colonialism, identity, and history.</p>
# </div>
# </div>
# <h2 style="color:MediumSeaGreen">Sights of culture and nature in Guyana</h2>
# <div style="text-align: center">
# <div style="display: inline-block; width: 400px; padding: 0 20px 0;  vertical-align:middle; ">
# <h3 style="text-align: left"><a href="https://en.wikipedia.org/wiki/Kaieteur_Falls">Kaieteur Falls</a></h3>
# <p style="text-align:justify; font-size: 16px">Located in the Kaieteur National Park, Kaieteur Falls is one of the most spectacular natural wonders in Guyana. It is one of the world's largest single-drop waterfalls and is surrounded by lush rainforest.</p>
# </div>
# <img src="https://lp-cms-production.imgix.net/2019-06/6e303b67f5cf51435e0691d6d9068cf2-kaieteur-falls.jpg" style="display: inline-block; width: 400px; height: 260px; padding: 0 20px 0">
# </div>
# <div style="text-align: center">
# <img src="https://iwokrama.org/wp-content/uploads/2016/05/ourwork-climatechange.jpg" style="display: inline-block; width: 400px; height: 260px; padding: 0 20px 0">
# <div style="display: inline-block; width: 400px; padding: 0 20px 0;  vertical-align:middle; ">
# <h3 style="text-align: left"><a href="https://en.wikipedia.org/wiki/Iwokrama_Forest">Iwokrama Forest Reserve</a></h3>
# <p style="text-align:justify; font-size: 16px">This vast rainforest is home to a diverse array of flora and fauna, including jaguars, giant otters, and hundreds of bird species. Visitors can go on guided hikes and nature walks to explore the forest.</p>
# </div>
# </div>
#
# <div style="text-align: center">
# <div style="display: inline-block; width: 400px; padding: 0 20px 0;  vertical-align:middle; ">
# <h3 style="text-align: left"><a href="https://en.wikipedia.org/wiki/St._George%27s_Cathedral,_Georgetown">St. George's Cathedral</a></h3>
# <p style="text-align:justify; font-size: 16px">Located in Georgetown, St. George's Cathedral is one of the tallest wooden churches in the world. It is an impressive example of Gothic architecture and features intricate stained glass windows and a towering spire.</p>
# </div>
# <img src=https://ntg.gov.gy/wp-content/uploads/2021/12/12.-St.-Georges-Cathedral-opt-1.jpg" style="display: inline-block; width: 400px; height: 260px; padding: 0 20px 0">
# </div>
# <div style="text-align: center">
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/6a/Walter_Roth_Museum_of_Anthropology_%2813695446384%29.jpg" style="display: inline-block; width: 400px; height: 260px; padding: 0 20px 0">
# <div style="display: inline-block; width: 400px; padding: 0 20px 0;  vertical-align:middle; ">
# <h3 style="text-align: left"><a href="https://en.wikipedia.org/wiki/Walter_Roth_Museum_of_Anthropology">Walter Roth Museum of Anthropology</a></h3>
# <p style="text-align:justify; font-size: 16px">This museum in Georgetown showcases the cultural history and traditions of Guyana's indigenous peoples, including the Wai Wai, Makushi, and Arawak.</p>
# </div>
#
# </div>
# <div style="text-align: center">
# <div style="display: inline-block; width: 400px; padding: 0 20px 0;  vertical-align:middle; ">
# <h3 style="text-align: left"><a href="https://en.wikipedia.org/wiki/Demerara_Harbour_Bridge">Demerara Harbour Bridge</a></h3>
# <p style="text-align:justify; font-size: 16px">This bridge spans the Demerara River and connects the cities of Georgetown and Linden. It is one of the longest floating bridges in the world and offers stunning views of the river and surrounding landscapes.</p>
# </div>
# <img src=https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2Hc5qXhkcQ0NtQ1eDagBCd0oMtFaR6lf-h0r252eAQfQDPpWVbmoVFg17yoPgAr5vt_Y&usqp=CAU" style="display: inline-block; width: 400px; height: 260px; padding: 0 20px 0">
# </div>
# <div style="text-align: center">
# <img src="https://i.ytimg.com/vi/yjkyHtBEXNM/maxresdefault.jpg" style="display: inline-block; width: 400px; height: 260px; padding: 0 20px 0">
# <div style="display: inline-block; width: 400px; padding: 0 20px 0;  vertical-align:middle; ">
# <h3 style="text-align: left"><a href="https://en.wikipedia.org/wiki/Shell_Beach,_Guyana">Shell Beach</a></h3>
# <p style="text-align:justify; font-size: 16px">Located on the northern coast of Guyana, Shell Beach is a protected nesting ground for sea turtles. Visitors can observe these magnificent creatures up close during nesting season.</p>
# </div>
# </div>
#
# </div>
# <div style="text-align: center">
# <div style="display: inline-block; width: 400px; padding: 0 20px 0;  vertical-align:middle; ">
# <h3 style="text-align: left"><a href="https://en.wikipedia.org/wiki/Guyana_National_Museum">Guyana National Museum</a></h3>
# <p style="text-align:justify; font-size: 16px">This museum in Georgetown features exhibits on the country's history and cultural heritage, including displays on Guyana's colonial past and its independence movement.</p>
# </div>
# <img src=http://exploreguyana.org/wp-content/uploads/2015/02/Guyana-National-Museum3.jpg" style="display: inline-block; width: 400px; height: 260px; padding: 0 20px 0">
# </div>
# <div style="text-align: center">
# <img src="https://oilnow.gy/wp-content/uploads/2021/04/Blog-1-8.jpg" style="display: inline-block; width: 400px; height: 260px; padding: 0 20px 0">
# <div style="display: inline-block; width: 400px; padding: 0 20px 0;  vertical-align:middle; ">
# <h3 style="text-align: left"><a href="https://en.wikipedia.org/wiki/Essequibo_River">Essequibo River</a></h3>
# <p style="text-align:justify; font-size: 16px">This is the longest river in Guyana, running for over 1,000 km. Visitors can go on boat tours to explore the river and its many tributaries, which are home to a diverse array of wildlife and bird species.</p>
# </div>
# </div>
#
# <h2 style="padding: 50px 0 0; color:MediumSeaGreen">Interesting Guyana Facts</h2>
# <ul style="padding: 0 100px; font-size: 16px">
# <li>Chicken, duck or lamb curry with rice are the main dishes at the birthday celebration. A family member usually bakes a fruit, black or sponge for the birthday boy/girl to cut. The person celebrating their birthday will wear something fancy.</li>
# <li>Aloe is a common medicine in Guyana and is used for a variety of ailments such as skin rashes, stomach ulcers, cuts, burns, sores, coughs and colds.</li>
# <li>Canada is currently the number one foreign investor in Guyana. It has been trading with Guyana since the 1920s.</li>
# <li>Guyana's most famous tourist attraction, the Kaieteur Falls, is among the five biggest waterfalls in the world. It is 250 m high, higher than Niagara Falls, and 100 m wide in the rainy season. It is surrounded by thick forest.</li>
# <li>Guyana's Omai Gold Mine is the largest open-pit gold mine in South America.</li>
# </ul>

# %% [markdown]
# TASK 2

# %%
def task_2():
    while True:
        try:
            num_list = list(map(int, input("Enter a list of whole numbers separated by space: ").split()))
            if all(isinstance(x, int) for x in num_list):
                break
            else:
                print("Invalid input! Please enter a list of whole numbers.")
        except ValueError:
            print("Invalid input! Please enter a list of whole numbers.")

    length = len(num_list)
    if length % 2 == 0:
        middle_index = length // 2
        return num_list[middle_index - 1], num_list[middle_index]
    else:
        middle_index = length // 2
        return num_list[middle_index]

# %%
task_2()
# Out:
# Enter a list of whole numbers separated by space: 53 17 92 41 68 29 77 83 11 45
# (68, 29)

# %%
task_2()
# Out:
# Enter a list of whole numbers separated by space: 6 28 71 12 45 83 39 52 97 22 64
# 83

# %%
task_2()
# Out:
# Enter a list of whole numbers separated by space: 9 5 y 9 2 2 t a 7 6
# Invalid input! Please enter a list of whole numbers.
# Enter a list of whole numbers separated by space: 1 2 3 4 ? 6 7 8
# Invalid input! Please enter a list of whole numbers.
# Enter a list of whole numbers separated by space: 1 2 3 4 5 6 7 8 9
# 5
